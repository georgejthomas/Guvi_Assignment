# %%
import csv

def registration():
    # ACCEPTING EMAIL ID/USERNAME AND PERFORMING VERIFICATION
    while True:
        email = input("\nEnter NEW Email ID: ")

        if '@' in email and '.' in email and email.index('.') > (email.index('@') + 1):
            subs = email.split('@')

            if subs[0].isalpha() == True:
                #print("Email ID Accepted")
                break
            else:
                print("YOU can only have Alphabets before the @")
        else:
            print("Email ID must have special characters \'@\',\'.\' and \'.\' must not come immediately after \'@\'")

    # ACCEPTING PASSWORD AND PERFORMING VERIFICATION
    while True:
        print("")
        password = input("\nEnter NEW Password. \nPassword must be of 5 -16 characters long. \nPassword must have Minimum: \n1 UPPERCASE CHARACTER \n1 LOWERCASE CHARACTER \n1 DIGIT \n1 SPECIAL CHARACTER FROM [ @, $, !, %, _, #, (, ), &, * ]\nEnter here: ")

        special_char = ['@', '$', '!', '%', '_', '#', '(', ')', '&', '*']
        dig_cnt = spechar_cnt = lowchar_cnt = uppchar_cnt = 0

        if len(password) >= 5 and len(password) <= 16:
            for ch in password:
                if ch.isupper():
                    uppchar_cnt += 1
                elif ch.islower():
                    lowchar_cnt += 1
                elif ch.isdigit():
                    dig_cnt += 1
                elif ch in special_char:
                    spechar_cnt += 1

            if uppchar_cnt == 0 or lowchar_cnt == 0 or dig_cnt == 0 or spechar_cnt == 0:
                print("Password must have Minimum: \n1 UPPERCASE CHARACTER \n1 LOWERCASE CHARACTER \n1 DIGIT \n1 SPECIAL CHARACTER FROM [ @, $, !, %, _, #, (, ), &, * ]")
            else:
                #print("Password accepted")
                break
        else:
            print("Password Length should be between 5 to 16 characters")

    # ADDING CREDENTIALS TO FILE
    login_id_pswrd = [email, password]

    fname = "login_creds.csv"

    with open(fname, 'a') as f:
        csvWriter = csv.writer(f)

        if csvWriter.writerow(login_id_pswrd):
            print("Credentials added")
        else:
            print("Not Successful")

# --------------------------------------------------------------------------------

def login():
    attempt = 1
    chk = 0
    try:
        while attempt <= 2:
            email = input("\nEnter Email ID: ")
            password = input("\nEnter Password: ")
            
            fname = "login_creds.csv"
            
            with open(fname, 'r') as f:
                csvReader = csv.reader(f)
                
                for x in csvReader:
                    if email == x[0]:
                        if password == x[1]:  # If both email id & password are correct
                            print("Hello", x[0], "Login Successful")
                            chk = 1
                            break
                        elif password != x[1] and attempt < 2:  # If email id is correct but password is wrong
                            print("Incorrect Login Credentials. Try Again")
                            attempt += 1
                            chk = 2
                            break
                        else:
                            print("Incorrect Login Credentials. 2 ATTEMPTS OVER")
                            password = x[1]
                            chk = 3
                            break
                    else:
                      chk = 0
                
                if chk == 0:
                    inval = input("Login credentials do NOT Exists \nWOULD YOU LIKE TO REGISTER NEW (Enter Y/y for YES or n/N for NO): ")
                    if inval in ('y', 'Y'):
                        registration()
                        break
                    else:
                        break
                elif chk == 1:
                    break
                elif chk == 3:
                    inval = input("ENTER 1 FOR FORGOT PASSWORD: ")
                    if inval == '1':
                        print("Email: ", email)
                        print("Password: ", password)
                        break
        
    except FileNotFoundError:
        fname = "login_creds.csv"
        with open(fname, 'a') as f:
            csvWriter = csv.writer(f)
            csvWriter.writerow(["Email", "Password"])
            print("Try Again")

# --------------------------------------------------------------------------------

# ------------MAIN BLOCK------------
while True:
    print("\nWELCOME \nENTER 1 TO LOGIN \nENTER 2 TO SIGN UP \\ REGISTER \nENTER 3 TO EXIT")
    userIn = input("ENTER YOUR OPTION: ")

    if userIn == "1":
        login()
    elif userIn == "2":
        registration()
    else:
        print("EXITING.. \nGOODBYE")
        break
# Out:
# WELCOME
# ENTER 1 TO LOGIN
# ENTER 2 TO SIGN UP \ REGISTER
# ENTER 3 TO EXIT
# ENTER YOUR OPTION: 2
#
# Enter NEW Email ID: @dd.com
# YOU can only have Alphabets before the @
#
# Enter NEW Email ID: sd.com
# Email ID must have special characters '@','.' and '.' must not come immediately after '@'
#
# Enter NEW Email ID: sde@lokm.com
#
#
# Enter NEW Password.
# Password must be of 5 -16 characters long.
# Password must have Minimum:
# 1 UPPERCASE CHARACTER
# 1 LOWERCASE CHARACTER
# 1 DIGIT
# 1 SPECIAL CHARACTER FROM [ @, $, !, %, _, #, (, ), &, * ]
# Enter here: def1SS@
# Credentials added
#
# WELCOME
# ENTER 1 TO LOGIN
# ENTER 2 TO SIGN UP \ REGISTER
# ENTER 3 TO EXIT
# ENTER YOUR OPTION: 1
#
# Enter Email ID: sdd@lok.com
#
# Enter Password: eess@!
# Login credentials do NOT Exists
#  WOULD YOU LIKE TO REGISTER NEW (Enter Y/y for YES or n/N for NO): y
#
# Enter NEW Email ID: sdd@lok.com
#
#
# Enter NEW Password.
# Password must be of 5 -16 characters long.
# Password must have Minimum:
# 1 UPPERCASE CHARACTER
# 1 LOWERCASE CHARACTER
# 1 DIGIT
# 1 SPECIAL CHARACTER FROM [ @, $, !, %, _, #, (, ), &, * ]
# Enter here: eess@123LK
# Credentials added
#
# WELCOME
# ENTER 1 TO LOGIN
# ENTER 2 TO SIGN UP \ REGISTER
# ENTER 3 TO EXIT
# ENTER YOUR OPTION: 1
#
# Enter Email ID: dde@mmkm.com
#
# Enter Password: qwwwss
# Login credentials do NOT Exists
#  WOULD YOU LIKE TO REGISTER NEW (Enter Y/y for YES or n/N for NO): n
#
# WELCOME
# ENTER 1 TO LOGIN
# ENTER 2 TO SIGN UP \ REGISTER
# ENTER 3 TO EXIT
# ENTER YOUR OPTION: 1
#
# Enter Email ID: gjt@gmail.com
#
# Enter Password: dddeew
# Incorrect Login Credentials. Try Again
#
# Enter Email ID: gjt@gmail.com
#
# Enter Password: qqqdd2
# Incorrect Login Credentials. 2 ATTEMPTS OVER
# ENTER 1 FOR FORGOT PASSWORD: 1
# Email:  gjt@gmail.com
# Password:  gjt1@GH
#
# WELCOME
# ENTER 1 TO LOGIN
# ENTER 2 TO SIGN UP \ REGISTER
# ENTER 3 TO EXIT
# ENTER YOUR OPTION: 1
#
# Enter Email ID: gjt@gmail.com
#
# Enter Password: gjt1@GH
# Hello gjt@gmail.com Login Successful
#
# WELCOME
# ENTER 1 TO LOGIN
# ENTER 2 TO SIGN UP \ REGISTER
# ENTER 3 TO EXIT
# ENTER YOUR OPTION: 3
# EXITING..
# GOODBYE
